# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacksymar/BaseDeDatos/blob/main/Copia_de_LimpiezaDeBase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
#  **Base 2021**

# %%
# %cd "/content/drive/MyDrive/Trabajo_de_grado/Bases_de_datos"
# Out:
# /content/drive/MyDrive/Trabajo_de_grado/Bases_de_datos

# %%
ruta = '/content/drive/MyDrive/Trabajo_de_grado/Bases_de_datos/fetal2021.csv'
data = pd.read_csv(ruta)

# %%
display(data)
# Out:
#        Unnamed: 0  cod_dpto  cod_munic  a_defun  sit_defun otrsitiode  \
# 0               0        23          1        1          1        NaN
# 1               1        17        380        1          1        NaN
# 2               2        70          1        1          1        NaN
# 3               3         5          1        1          1        NaN
# 4               4        54          1        1          1        NaN
# ...           ...       ...        ...      ...        ...        ...
# 30704       30704        95          1        1          1        NaN
# 30705       30705        11          1        1          1        NaN
# 30706       30706        27          1        1          1        NaN
# 30707       30707        88          1        1          1        NaN
# 30708       30708         8          1        1          1        NaN
#
#        tipo_defun   ano  mes  hora  ...  c_muerteb  c_muertec  c_muerted  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'cod_dpto', 'cod_munic', 'a_defun', 'sit_defun',
#        'otrsitiode', 'tipo_defun', 'ano', 'mes', 'hora', 'minutos', 'sexo',
#        'codpres', 'codptore', 'codmunre', 'area_res', 'seg_social',
#        'idadmisalud', 'p_pman_iris', 'cons_exp', 'mu_parto', 't_parto',
#        'tipo_emb', 't_ges', 't_ges_agru_cie', 'peso_nac', 'edad_madre',
#        'n_hijosv', 'n_hijosm', 'est_civm', 'niv_edum', 'ultcurmad', 'codocur',
#        'codmunoc', 'c_muerte', 'c_muerteb', 'c_muertec', 'c_muerted',
#        'c_muertee', 'asis_med', 'causa_mult', 'c_bas1', 'causa_667',
#        'idprofcer', 'cau_homol'],
#       dtype='object')

# %%
data[['cod_dpto', 'seg_social', 'niv_edum', 'edad_madre']]
# Out:
#        cod_dpto  seg_social  niv_edum  edad_madre
# 0            23           2         3         1.0
# 1            17           2         9         6.0
# 2            70           2         4         5.0
# 3             5           1         9         4.0
# 4            54           5        99         3.0
# ...         ...         ...       ...         ...
# 30704        95           1        99         7.0
# 30705        11           1         4         4.0
# 30706        27           2         2         6.0
# 30707        88           2         4         4.0
# 30708         8           2         3         4.0
#
# [30709 rows x 4 columns]

# %%
base2021 = pd.DataFrame(dict(data[['cod_dpto', 'seg_social', 'niv_edum', 'edad_madre']]))

# %%
base2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30709 entries, 0 to 30708
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cod_dpto    30709 non-null  int64
#  1   seg_social  30709 non-null  int64
#  2   niv_edum    30709 non-null  int64
#  3   edad_madre  30709 non-null  float64
# dtypes: float64(1), int64(3)
# memory usage: 959.8 KB

# %%
base2021.isnull().sum()
# Out:
# cod_dpto      0
# seg_social    0
# niv_edum      0
# edad_madre    0
# dtype: int64

# %% [markdown]
# **Base 2020**

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Trabajo_de_grado/Bases_de_datos/fetal2020.csv')
# Out:
# <ipython-input-11-5b67e43af9b5>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv('/content/drive/MyDrive/Trabajo_de_grado/Bases_de_datos/fetal2020.csv')

# %%
display(data1)
# Out:
#        Unnamed: 0  cod_dpto  cod_munic  a_defun  sit_defun otrsitiode  \
# 0               0        70          1        1          1        NaN
# 1               1        11          1        1          1        NaN
# 2               2        11          1        1          1        NaN
# 3               3        11          1        1          1        NaN
# 4               4        11          1        1          1        NaN
# ...           ...       ...        ...      ...        ...        ...
# 33322       33322        41          1        1          1        NaN
# 33323       33323        11          1        1          1        NaN
# 33324       33324        11          1        1          1        NaN
# 33325       33325        76        109        1          1        NaN
# 33326       33326        11          1        1          1        NaN
#
#        tipo_defun     ano  mes  hora  ...  c_muerteb  c_muertec  c_muerted  \
# ...

# %%
base2020 = pd.DataFrame(dict(data1[['cod_dpto', 'seg_social', 'niv_edum', 'edad_madre']]))

# %%
print(base2020)
# Out:
#        cod_dpto  seg_social  niv_edum  edad_madre
# 0            70           2         4         3.0
# 1            11           1         4         5.0
# 2            11           5         9         5.0
# 3            11           5         5         3.0
# 4            11           5         4         2.0
# ...         ...         ...       ...         ...
# 33322        41           2         2         5.0
# 33323        11           2         2         2.0
# 33324        11           5         4         3.0
# 33325        76           1         3         5.0
# 33326        11           5         4         5.0
#
# [33327 rows x 4 columns]

# %%
base2021.isnull().sum()
# Out:
# cod_dpto      0
# seg_social    0
# niv_edum      0
# edad_madre    0
# dtype: int64

# %%
#concatenar las bases
base201 = pd.concat([base2020,base2021], ignore_index=True)
base201
# Out:
#        cod_dpto  seg_social  niv_edum  edad_madre
# 0            70           2         4         3.0
# 1            11           1         4         5.0
# 2            11           5         9         5.0
# 3            11           5         5         3.0
# 4            11           5         4         2.0
# ...         ...         ...       ...         ...
# 64031        95           1        99         7.0
# 64032        11           1         4         4.0
# 64033        27           2         2         6.0
# 64034        88           2         4         4.0
# 64035         8           2         3         4.0
#
# [64036 rows x 4 columns]

# %%
df = pd.DataFrame(dict(base201))
df
# Out:
#        cod_dpto  seg_social  niv_edum  edad_madre
# 0            70           2         4         3.0
# 1            11           1         4         5.0
# 2            11           5         9         5.0
# 3            11           5         5         3.0
# 4            11           5         4         2.0
# ...         ...         ...       ...         ...
# 64031        95           1        99         7.0
# 64032        11           1         4         4.0
# 64033        27           2         2         6.0
# 64034        88           2         4         4.0
# 64035         8           2         3         4.0
#
# [64036 rows x 4 columns]

# %%
base201.isnull().sum()
# Out:
# cod_dpto      0
# seg_social    0
# niv_edum      0
# edad_madre    0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >
